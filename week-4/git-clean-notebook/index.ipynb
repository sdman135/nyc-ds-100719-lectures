# %% [markdown]
# <h1 style='text-align:center'>Project Management</h1>

# %% [markdown]
# ## Working Together

# %% [markdown]
# <img src='images/teamwork.gif'/>

# %% [markdown]
# #### Steps of a Data Science Project

# %% [markdown]
# - Define the problem
# - Where to get data from
#     - Dataset
#     - API
#     - Web Scraping
# - Data Cleaning
# - EDA
# - Modeling
# - Validation
# - Readme, Final notebooks

# %% [markdown]
# #### Guidelines for working together

# %% [markdown]
# - Discuss how you each prefer to work, strengths/weaknesses, things you’re really interested in working on
# - Create a workflow that is going to work for the both of you
# - After deciding on a project topic or dataset you want to explore, break down the Data Gathering process into small steps (call data from “x” API, scrape “y” website, clean data, merge data etc.)
#     - If a particular task is complex split it even further - i.e. you have multiple pages of the same website that need to be scraped and each require different scripts then each script is a different task
#     - Each unique API and website should be a separate task
# - Assign/Pick one to two tasks (2-4 hours of work worth of tasks) for each partner.
# - After task(s) are complete, meet up and review each others code, ask/answer questions, marge code (if applicable) and cross test
# - Repeat this process until all tasks for Data Gathering are done.
# - Continue with this process for the remainder of the major steps (EDA, Modeling, Validation, Final Cleanup/Readme)

# %% [markdown]
# ## Collaborating on Git

# %% [markdown]
# We use git (and GitHub) to collaborate on a project. Many people can work on a single project simultaneously.
#
# Generally, many people can work on the same file and when ready, git allows you to merge the file into one file. Git also has tools to help manage any conflicts that might arise in the merging process.
#
# When working with Jupyter Notebooks, certain considerations to be made because git cannot cleanly merge .ipynb files. Therefore, when working in pairs, use separate notebooks (different names) to test code and utilize functions in .py files for easy merging.

# %% [markdown]
# #### Perform the following steps with partners:
#
# - One person initializes a git repository on GitHub
# - Add other person(s) as collaborators on GitHub (under settings)
# - Both partners clone down repository onto their own computers
# - Both partners create a new branch on their local repository 'git checkout -b name-wip-what-you-are-working-on'
# - Both partners create a new .ipynb file with different names
# - Git add *, git commit -m "message", git push (you'll see an error - follow the instruction)
# - Create a pull request
# - Marvel in your mastery of git

# %% [markdown]
# ## Clean Notebooks

# %% [markdown]
# #### Why do notebooks need to kept clean?
#
# #### Why should we comment our code?

# %% [markdown]
# ### Work in Pairs
# - Cleanup code below (create functions, import from importme.py)
# - Push to GitHub
# - Create pull request

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('baseball_stats.csv')

# %%
df
# Out:
#       Unnamed: 0  id                  name  id.1  team_id league division  \
# 0              0   1  Arizona Diamondbacks     1        1     NL     West
# 1              1   1  Arizona Diamondbacks     2        1     NL     West
# 2              2   1  Arizona Diamondbacks     3        1     NL     West
# 3              3   1  Arizona Diamondbacks     4        1     NL     West
# 4              4   1  Arizona Diamondbacks     5        1     NL     West
# 5              5   1  Arizona Diamondbacks     6        1     NL     West
# 6              6   1  Arizona Diamondbacks     7        1     NL     West
# 7              7   1  Arizona Diamondbacks     8        1     NL     West
# 8              8   1  Arizona Diamondbacks     9        1     NL     West
# 9              9   1  Arizona Diamondbacks    10        1     NL     West
# 10            10   1  Arizona Diamondbacks    11        1     NL     West
# 11            11   1  Arizona Diamondbacks    12        1     NL     West
# 12            12   1  Arizona Diamondbacks    13        1     NL     West
# 7     2011    94          731        172        0.250  0.736     28.2
# 8     2010    65          713        180        0.250  0.740     26.8
# 9     2009    70          720        173        0.253  0.742     26.5
# 10    2008    82          720        159        0.251  0.742     26.7
# 11    2007    90          712        171        0.250  0.734     26.6
# 12    2006    76          773        160        0.267  0.755     29.7
# 13    2005    77          696        191        0.256  0.754     30.3
# 14    2004    51          615        135        0.253  0.703     28.9
# 15    2003    84          717        152        0.263  0.746     30.6
# 16    2002    98          819        165        0.267  0.769     31.7
# 17    2001    92          818        208        0.267  0.783     31.9
# 18    2000    85          792        179        0.265  0.763     30.8
# 19    1999   100          908        216        0.277  0.805     30.0
# 20    1998    65          665        159        0.246  0.707     27.8
# 21    2018    90          759        175        0.257  0.742     27.4
# 22    2017    72          732        165        0.263  0.738     28.6
# 23    2016    68          649        122        0.255  0.705     28.9
# 24    2015    67          573        100        0.251  0.674     28.8
# 25    2014    79          573        123        0.241  0.665     26.8
# 26    2013    96          688        181        0.249  0.723     26.8
# 27    2012    94          700        149        0.247  0.709     28.5
# 28    2011    89          641        173        0.243  0.695     28.9
# 29    2010    91          738        139        0.258  0.740     28.6
# ...    ...   ...          ...        ...          ...    ...      ...
# 2624  1998    65          644        147        0.249  0.704     25.9
# 2625  1997    78          691        172        0.258  0.741     27.7
# 2626  1996    88          741        148        0.262  0.733     27.4
# 2627  1995    66          621        118        0.259  0.714     26.2
# 2628  1994    74          585        108        0.278  0.778     26.2
# 2629  1993    94          732        122        0.257  0.712     25.7
# 2630  1992    87          648        102        0.252  0.682     27.4
# 2631  1991    71          579         95        0.246  0.666     27.7
# 2632  1990    85          662        114        0.250  0.692     27.7
# 2633  1989    81          632        100        0.247  0.681     28.9
# 2634  1988    81          628        107        0.251  0.682     28.2
# 2635  1987    91          741        120        0.265  0.729     27.5
# 2636  1986    78          637        110        0.254  0.701     27.4
# 2637  1985    84          633        118        0.247  0.685     27.7
# 2638  1984    78          593         96        0.251  0.674     28.8
# 2639  1983    82          677        102        0.264  0.713     28.4
# 2640  1982    86          697        133        0.262  0.720     27.9
# 2641  1981    60          443         81        0.246  0.686     26.9
# 2642  1980    90          694        114        0.257  0.712     27.1
# 2643  1979    95          701        143        0.264  0.728     27.3
# 2644  1978    76          633        121        0.254  0.685     27.2
# 2645  1977    75          665        138        0.260  0.720     26.4
# 2646  1976    55          531         94        0.235  0.631     25.1
# 2647  1975    75          601         98        0.244  0.664     24.7
# 2648  1974    79          662         86        0.254  0.686     27.7
# 2649  1973    79          668        125        0.251  0.704     27.7
# 2650  1972    70          513         91        0.234  0.628     26.9
# 2651  1971    71          622         88        0.246  0.666     28.3
# 2652  1970    73          687        136        0.237  0.687     27.7
# 2653  1969    52          582        125        0.240  0.669     27.6
#
# [2654 rows x 14 columns]

# %%
teams = df.name.unique()

# %%
df['team_ratio'] = df['wins']/df['runs_scored']

# %%
team_ratio = df[df.name == 'Arizona Diamondbacks'][['year', 'team_ratio']]

# %%
plt.bar(team_ratio['year'], team_ratio['team_ratio'])
# Out:
# <BarContainer object of 21 artists>
